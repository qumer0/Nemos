-- %% [markdown]
-- # [haberler]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [haberler]    Script Date: 30.05.2024 15:14:54 ******/
CREATE DATABASE [haberler]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'haberler', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\haberler.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'haberler_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\haberler_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [haberler] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [haberler].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [haberler] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [haberler] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [haberler] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [haberler] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [haberler] SET ARITHABORT OFF 
GO
ALTER DATABASE [haberler] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [haberler] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [haberler] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [haberler] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [haberler] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [haberler] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [haberler] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [haberler] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [haberler] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [haberler] SET  DISABLE_BROKER 
GO
ALTER DATABASE [haberler] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [haberler] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [haberler] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [haberler] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [haberler] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [haberler] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [haberler] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [haberler] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [haberler] SET  MULTI_USER 
GO
ALTER DATABASE [haberler] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [haberler] SET DB_CHAINING OFF 
GO
ALTER DATABASE [haberler] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [haberler] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [haberler] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [haberler] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [haberler] SET QUERY_STORE = ON
GO
ALTER DATABASE [haberler] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[tbl_admin]

-- %%
USE [haberler]
GO

-- %%
/****** Object:  Table [dbo].[tbl_admin]    Script Date: 30.05.2024 15:14:55 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_admin](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[username] [nvarchar](50) NOT NULL,
	[password] [nvarchar](64) NOT NULL,
	[mail] [nvarchar](200) NOT NULL,
	[guvenlik_sorusu_id] [int] NOT NULL,
	[guvenlik_cevap] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_tbl_admin] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_haberler]

-- %%
/****** Object:  Table [dbo].[tbl_haberler]    Script Date: 30.05.2024 15:14:55 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_haberler](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[baslik] [nvarchar](200) NULL,
	[icerik] [nvarchar](max) NOT NULL,
	[resimurl] [nvarchar](max) NOT NULL,
	[tarih] [datetime] NOT NULL,
	[etiket] [nvarchar](50) NULL,
 CONSTRAINT [PK_tbl_haberler] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_sorular]

-- %%
/****** Object:  Table [dbo].[tbl_sorular]    Script Date: 30.05.2024 15:14:55 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_sorular](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[guvenlik_sorusu] [nvarchar](500) NOT NULL,
 CONSTRAINT [PK_tbl_sorular] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_admin]

-- %%
SET IDENTITY_INSERT [dbo].[tbl_admin] ON 
INSERT [dbo].[tbl_admin] ([id], [username], [password], [mail], [guvenlik_sorusu_id], [guvenlik_cevap]) VALUES (7, N'admin', N'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', N'admin@admin.com', 1, N'kuki')
INSERT [dbo].[tbl_admin] ([id], [username], [password], [mail], [guvenlik_sorusu_id], [guvenlik_cevap]) VALUES (8, N'admin1', N'6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b', N'admin1@admin.com', 3, N'mor')
SET IDENTITY_INSERT [dbo].[tbl_admin] OFF
GO

-- %% [markdown]
-- # [dbo].[tbl_haberler]

-- %%
SET IDENTITY_INSERT [dbo].[tbl_haberler] ON 
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (10, N'a', N'a', N'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg/220px-Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg', CAST(N'2014-01-01T00:00:00.000' AS DateTime), N'Gündem')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (12, N'sdffsfsdfsdfdf ', N'sdfssdfsdfs dsf sdfsdfsdf', N'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ9mF5WlorCSRoe6VLrweaj6dL9adhEzWs8qA&s', CAST(N'2002-01-01T00:00:00.000' AS DateTime), N'Kültür-Sanat')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (13, N'asdasd', N'asd', N'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTWn_dEfUJUxmThlk-pHL3P74lY7EFx0IImoQ&s', CAST(N'2005-06-02T00:00:00.000' AS DateTime), N'Dünya')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (14, N'sdasdasd', N'asdasdasdasdasdasd', N'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT0iPESuPvryqpSk-K5aHNnbLuh9BrHdJnHaw&s', CAST(N'2024-02-08T00:00:00.000' AS DateTime), N'Ekonomi')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (15, N'asdadasd', N'asdasdasd', N'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQJx57Su_TmiSAYIx2Y-WX1jneqUEeg-gg_zQ&s', CAST(N'2005-12-08T00:00:00.000' AS DateTime), N'Spor')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (16, N'NUasdasdasdasdadL', N'asdasdasdasdasdasdasd', N'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTfnwxMj0gIGS2O0_IFqfNlwSy6qxRPjkPGeg&s', CAST(N'2009-03-05T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (22, N'asdasd asdasdasdsad asdasdas', N'sdaksjdıaj asıd asod ash ıahsdash saodhoasdasndojas a asdasd asdjasdıajsdıj asdjıasjdıaj sıjd aısjd ıasjdıjasıdnasıdnaısjıasjıa    asasd adsasdaskdnasj njasdnajsdajskndaksn ndasndajsndj najdsnajsdnjasdnjlasndjn jandnajsdnjnj njansdjansdjansdjnasjdnajs ndn dsadnasdnasjldnljasndjasndj naj sndjansjdn jasndsjasndjl ansldn ajlsndjasndjlansdjna jlsn jalsdnjlasnd jsan jsnd lansdlnasldna lsdn landlansdknaslkdn alndsljasn an sdnalsnd   ', N'data:image/jpeg;base64,...', CAST(N'2007-09-05T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (27, N'Yeni Ekonomik Tedbirler Açıklandı', N'Hükümet, ekonomik büyümeyi teşvik etmek için bir dizi yeni tedbir açıkladı. Bu tedbirler arasında vergi indirimleri ve teşvik paketleri bulunuyor.', N'data:image/jpeg;base64,...', CAST(N'2024-05-20T00:00:00.000' AS DateTime), N'Ekonomi')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (28, N'Kültür-Sanat Festivali Başladı', N'Bu yılki Kültür-Sanat Festivali, dünya çapından birçok sanatçının katılımıyla başladı. Festivalde çeşitli etkinlikler ve sergiler yer alacak.', N'data:image/jpeg;base64,...', CAST(N'2024-05-21T00:00:00.000' AS DateTime), N'Kültür-Sanat')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (29, N'Teknoloji Fuarında Yeni İcatlar Tanıtıldı', N'Bu yılki teknoloji fuarında, birçok yeni icat ve inovasyon tanıtıldı. Fuara katılan firmalar, en yeni teknolojilerini sergiledi.', N'data:image/jpeg;base64,...', CAST(N'2024-05-22T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (30, N'Spor Dünyasında Büyük Transfer', N'Ünlü futbolcu, dev bir transfer ücreti karşılığında başka bir takıma transfer oldu. Bu transfer, spor dünyasında büyük yankı uyandırdı.', N'data:image/jpeg;base64,...', CAST(N'2024-05-23T00:00:00.000' AS DateTime), N'Spor')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (31, N'Dünya Genelinde İklim Değişikliği Protestoları', N'Dünya genelinde milyonlarca insan, iklim değişikliği ile mücadele için sokaklara döküldü. Protestolar barışçıl bir şekilde devam ediyor.', N'data:image/jpeg;base64,...', CAST(N'2024-05-24T00:00:00.000' AS DateTime), N'Dünya')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (32, N'Gündemdeki Yeni Sağlık Reformu', N'Sağlık bakanlığı, yeni bir sağlık reformu planını duyurdu. Bu plan, sağlık hizmetlerine erişimi kolaylaştırmayı amaçlıyor.', N'data:image/jpeg;base64,...', CAST(N'2024-05-25T00:00:00.000' AS DateTime), N'Gündem')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (33, N'Ekonomik Büyüme Beklentileri Artıyor', N'Analistler, yılın ikinci yarısında ekonomik büyümenin hızlanmasını bekliyor. Yatırımcılar ise temkinli bir iyimserlik içinde.', N'data:image/jpeg;base64,...', CAST(N'2024-05-26T00:00:00.000' AS DateTime), N'Ekonomi')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (34, N'Yerel Tiyatro Oyunu Büyük İlgi Gördü', N'Yerel bir tiyatro grubu tarafından sahnelenen oyun, büyük ilgi gördü ve izleyicilerden tam not aldı.', N'data:image/jpeg;base64,...', CAST(N'2024-05-27T00:00:00.000' AS DateTime), N'Kültür-Sanat')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (35, N'Yeni Akıllı Telefon Modeli Tanıtıldı', N'Ünlü teknoloji firması, yeni akıllı telefon modelini tanıttı. Telefon, gelişmiş özellikleri ve şık tasarımı ile dikkat çekiyor.', N'data:image/jpeg;base64,...', CAST(N'2024-05-28T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (36, N'Basketbol Ligi Şampiyonu Belli Oldu', N'Basketbol ligi final maçında kazanan takım şampiyonluğunu ilan etti. Maç, büyük bir heyecana sahne oldu.', N'data:image/jpeg;base64,...', CAST(N'2024-05-29T00:00:00.000' AS DateTime), N'Spor')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (37, N'Uluslararası İklim Zirvesi Başladı', N'Dünya liderleri, iklim değişikliği ile mücadele için uluslararası zirvede bir araya geldi. Zirvede önemli kararlar alınması bekleniyor.', N'data:image/jpeg;base64,...', CAST(N'2024-05-30T00:00:00.000' AS DateTime), N'Dünya')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (38, N'Yeni Ulaşım Projesi Tanıtıldı', N'Ulaştırma bakanlığı, yeni bir ulaşım projesi tanıttı. Proje, şehir içi ulaşımı büyük ölçüde kolaylaştıracak.', N'data:image/jpeg;base64,...', CAST(N'2024-06-01T00:00:00.000' AS DateTime), N'Gündem')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (39, N'Kripto Para Piyasasında Dalgalanmalar', N'Kripto para piyasasında son günlerde büyük dalgalanmalar yaşanıyor. Uzmanlar, yatırımcıları dikkatli olmaları konusunda uyarıyor.', N'data:image/jpeg;base64,...', CAST(N'2024-06-02T00:00:00.000' AS DateTime), N'Ekonomi')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (40, N'Sanat Galerisinde Yeni Sergi Açıldı', N'Sanat galerisinde yeni açılan sergi, sanatseverler tarafından büyük ilgi gördü. Sergide yer alan eserler büyük beğeni topladı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-03T00:00:00.000' AS DateTime), N'Kültür-Sanat')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (41, N'Yapay Zeka Konferansı Düzenlendi', N'Yapay zeka alanında çalışan uzmanlar, düzenlenen konferansta bir araya geldi. Konferansta yeni teknolojiler ve gelişmeler tartışıldı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-04T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (42, N'Maraton Yarışması Büyük İlgi Gördü', N'Şehirde düzenlenen maraton yarışması, büyük ilgi gördü. Yarışmaya binlerce kişi katıldı ve renkli görüntüler oluştu.', N'data:image/jpeg;base64,...', CAST(N'2024-06-05T00:00:00.000' AS DateTime), N'Spor')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (43, N'Dünya Çevre Günü Etkinlikleri', N'Dünya Çevre Günü kapsamında birçok etkinlik düzenlendi. Etkinliklerde çevre bilincini artırmaya yönelik faaliyetler yapıldı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-06T00:00:00.000' AS DateTime), N'Dünya')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (44, N'Yeni Eğitim Reformu Yolda', N'Milli eğitim bakanlığı, yeni bir eğitim reformu planını duyurdu. Bu plan, eğitim sisteminde önemli değişiklikler getirecek.', N'data:image/jpeg;base64,...', CAST(N'2024-06-07T00:00:00.000' AS DateTime), N'Gündem')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (45, N'Borsa Endekslerinde Dalgalanma', N'Borsa endekslerinde son günlerde dalgalanmalar yaşanıyor. Uzmanlar, piyasaların yakın takip edilmesi gerektiğini belirtiyor.', N'data:image/jpeg;base64,...', CAST(N'2024-06-08T00:00:00.000' AS DateTime), N'Ekonomi')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (46, N'Tiyatro Festivali Coşkuyla Sona Erdi', N'Bu yıl düzenlenen tiyatro festivali, büyük bir coşkuyla sona erdi. Festivalde birçok ödül sahiplerini buldu.', N'data:image/jpeg;base64,...', CAST(N'2024-06-09T00:00:00.000' AS DateTime), N'Kültür-Sanat')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (47, N'Robotik Teknolojilerde Yeni Gelişmeler', N'Robotik teknolojilerde yaşanan yeni gelişmeler, teknoloji dünyasında heyecan yarattı. Birçok yeni robot modeli tanıtıldı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-10T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (48, N'Futbol Takımı Yeni Sezona Hazır', N'Ünlü futbol takımı, yeni sezona hazırlıklarını tamamladı. Takım, yeni sezonda büyük başarılara imza atmayı hedefliyor.', N'data:image/jpeg;base64,...', CAST(N'2024-06-11T00:00:00.000' AS DateTime), N'Spor')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (49, N'Dünya Sağlık Örgütü Uyarısı', N'Dünya Sağlık Örgütü, artan salgın hastalıklar konusunda uyarılarda bulundu. Alınması gereken önlemler hakkında bilgi verildi.', N'data:image/jpeg;base64,...', CAST(N'2024-06-12T00:00:00.000' AS DateTime), N'Dünya')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (50, N'Yeni Toplu Taşıma Sistemi Kullanıma Açıldı', N'Şehirde yeni toplu taşıma sistemi kullanıma açıldı. Sistem, şehir içi ulaşımı büyük ölçüde rahatlatacak.', N'data:image/jpeg;base64,...', CAST(N'2024-06-13T00:00:00.000' AS DateTime), N'Gündem')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (51, N'Küresel Ekonomi Raporu Yayınlandı', N'Küresel ekonomi raporu yayınlandı. Raporda, dünya ekonomisinin durumu ve geleceğe yönelik beklentiler değerlendirildi.', N'data:image/jpeg;base64,...', CAST(N'2024-06-14T00:00:00.000' AS DateTime), N'Ekonomi')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (52, N'Sanatçılar Dayanışma Gecesi Düzenledi', N'Sanatçılar, dayanışma gecesinde bir araya geldi. Gece boyunca çeşitli etkinlikler düzenlendi ve bağışlar toplandı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-15T00:00:00.000' AS DateTime), N'Kültür-Sanat')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (53, N'Yeni Nesil Bilgisayarlar Tanıtıldı', N'Yeni nesil bilgisayarlar, düzenlenen lansman etkinliğinde tanıtıldı. Bilgisayarlar, yüksek performans ve şık tasarımları ile dikkat çekiyor.', N'data:image/jpeg;base64,...', CAST(N'2024-06-16T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (54, N'Yüzme Şampiyonası Tamamlandı', N'Şehirde düzenlenen yüzme şampiyonası tamamlandı. Şampiyonada birçok sporcu çeşitli kategorilerde madalya kazandı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-17T00:00:00.000' AS DateTime), N'Spor')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (55, N'Uluslararası Barış Zirvesi Sona Erdi', N'Uluslararası Barış Zirvesi sona erdi. Zirvede, dünya barışı ve güvenliği konularında önemli kararlar alındı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-18T00:00:00.000' AS DateTime), N'Dünya')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (56, N'Yeni Anayasa Taslağı Açıklandı', N'Yeni anayasa taslağı, hükümet tarafından açıklandı. Taslakta, vatandaş haklarına yönelik önemli düzenlemeler yer alıyor.', N'data:image/jpeg;base64,...', CAST(N'2024-06-19T00:00:00.000' AS DateTime), N'Gündem')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (57, N'Enerji Piyasasında Yenilikler', N'Enerji piyasasında yaşanan yenilikler, sektör temsilcileri tarafından değerlendirildi. Yeni projeler ve yatırımlar hakkında bilgi verildi.', N'data:image/jpeg;base64,...', CAST(N'2024-06-20T00:00:00.000' AS DateTime), N'Ekonomi')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (58, N'Müzik Festivali Büyük İlgi Gördü', N'Şehirde düzenlenen müzik festivali, büyük ilgi gördü. Festivalde birçok ünlü sanatçı sahne aldı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-21T00:00:00.000' AS DateTime), N'Kültür-Sanat')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (59, N'Yapay Zeka Alanında Yeni Gelişmeler', N'Yapay zeka alanında yaşanan yeni gelişmeler, teknoloji dünyasında heyecan yarattı. Birçok yeni AI projesi tanıtıldı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-22T00:00:00.000' AS DateTime), N'Teknoloji')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (60, N'Tenis Turnuvası Şampiyonu Belli Oldu', N'Şehirde düzenlenen tenis turnuvası şampiyonu belli oldu. Turnuvada büyük çekişmeler yaşandı ve izleyiciler keyifli anlar yaşadı.', N'data:image/jpeg;base64,...', CAST(N'2024-06-23T00:00:00.000' AS DateTime), N'Spor')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (61, N'Dünya Sağlık Zirvesi Başladı', N'Dünya Sağlık Zirvesi başladı. Zirvede, küresel sağlık sorunları ve çözüm önerileri tartışılacak.', N'data:image/jpeg;base64,...', CAST(N'2024-06-24T00:00:00.000' AS DateTime), N'Dünya')
INSERT [dbo].[tbl_haberler] ([id], [baslik], [icerik], [resimurl], [tarih], [etiket]) VALUES (62, N'Yeni Ulaşım Projesi İmzalandı', N'Şehirde yeni ulaşım projesi için imzalar atıldı. Proje, şehiriçi ulaşımı büyük ölçüde kolaylaştıracak.', N'data:image/jpeg;base64,...', CAST(N'2024-06-25T00:00:00.000' AS DateTime), N'Gündem')
SET IDENTITY_INSERT [dbo].[tbl_haberler] OFF
GO

-- %% [markdown]
-- # [dbo].[tbl_sorular]

-- %%
SET IDENTITY_INSERT [dbo].[tbl_sorular] ON 
INSERT [dbo].[tbl_sorular] ([id], [guvenlik_sorusu]) VALUES (1, N'İlk Evcil Hayvanınızın Adı')
INSERT [dbo].[tbl_sorular] ([id], [guvenlik_sorusu]) VALUES (2, N'İlk Öğretmeninizin Adı')
INSERT [dbo].[tbl_sorular] ([id], [guvenlik_sorusu]) VALUES (3, N'Yaşadığınızı Şehir')
INSERT [dbo].[tbl_sorular] ([id], [guvenlik_sorusu]) VALUES (4, N'Doğum yeriniz Neresi')
SET IDENTITY_INSERT [dbo].[tbl_sorular] OFF
GO

-- %% [markdown]
-- # [FK_tbl_admin_tbl_sorular]

-- %%
ALTER TABLE [dbo].[tbl_admin]  WITH CHECK ADD  CONSTRAINT [FK_tbl_admin_tbl_sorular] FOREIGN KEY([guvenlik_sorusu_id])
REFERENCES [dbo].[tbl_sorular] ([id])
GO
ALTER TABLE [dbo].[tbl_admin] CHECK CONSTRAINT [FK_tbl_admin_tbl_sorular]
GO

-- %% [markdown]
-- # [haberler]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [haberler] SET  READ_WRITE 
GO
